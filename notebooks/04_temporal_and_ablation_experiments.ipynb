# %% [markdown]
# # 🔬 Research Notebook 04: Experiments E1, E2 & E5 (Baseline, Temporal & Ablation)
# ### *ML Benchmarking & Feature Ablation Study*
#
# Evaluating baseline classifiers (E1), temporal generalization split (E2), and feature ablation settings (E5).

# %%
import pandas as pd
import sys, os
sys.path.append('..')
e1_df = pd.read_csv('../results/metrics/E1_leakage_free_baseline.csv')
ablation_df = pd.read_csv('../results/metrics/E5_ablation_study.csv')
print("Experiment E1 Baseline Benchmark:")
display(e1_df)
print("\nExperiment E5 Ablation Study:")
display(ablation_df)
# Out:
# Experiment E1 Baseline Benchmark:
#                            Model Name Accuracy Precision  Recall F1 Score  \
# 0                  XGBoost Classifier   90.11%    93.70%  88.02%   90.77%
# 1            Random Forest Classifier   79.01%    88.58%  71.20%   78.95%
# 2            Decision Tree Classifier   78.09%    81.54%  78.03%   79.75%
# 3  Linear Discriminant Analysis (LDA)   72.23%    84.27%  61.19%   70.90%
# 4  Support Vector Machine (LinearSVC)   72.13%    83.57%  61.71%   71.00%
# 5                 Logistic Regression   71.69%    81.63%  62.95%   71.09%
# 6                Gaussian Naive Bayes   69.45%    79.92%  59.74%   68.37%
#
#   ROC-AUC  PR-AUC Training Time  Acc_num  F1_num  ROC_num
# 0  96.13%  96.88%        56.33s    90.11   90.77    96.13
# 1  91.06%  92.91%        19.73s    79.01   78.95    91.06
# 2  82.03%  87.12%         4.30s    78.09   79.75    82.03
# 3  77.32%  83.28%         0.37s    72.23   70.90    77.32
# ...
