# %% [markdown]
# # 🔬 Research Notebook 07: Geographic & Shipping Mode Robustness (Steps 11–12)
# ### *Experiment E7: Cross-Market Generalization & Shipping Mode Analysis*
#
# Evaluating cross-market robustness and shipping mode dynamics.

# %%
import pandas as pd
import sys, os
sys.path.append('..')
geo_df = pd.read_csv('../results/metrics/E7_geographic_robustness.csv')
print("Experiment E7 Geographic Robustness:")
display(geo_df)
# Out:
# Experiment E7 Geographic Robustness:
#                                Market Group  Sample Size Late Delivery Rate
# 0         Training Markets (Europe + LATAM)        89172             55.12%
# 1  Out-of-Domain Test Market (Pacific Asia)        35481             55.63%
