# %% [markdown]
# # 🔬 Research Notebook 06: TreeSHAP Explainability Analysis (Step 10)
# ### *Experiment E6: SHAP Summary & Dependence Plotting*
#
# Explaining the final calibrated XGBoost model using TreeSHAP values.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image
import sys, os
sys.path.append('..')
print("TreeSHAP explainability plots generated in visuals/E6_shap/")
# Out:
# TreeSHAP explainability plots generated in visuals/E6_shap/
