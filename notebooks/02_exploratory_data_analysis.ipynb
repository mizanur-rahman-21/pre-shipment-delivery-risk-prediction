# %% [markdown]
# # 🔬 Research Notebook 02: Exploratory Data Analysis (EDA)
# ### *Logistics & Geographic Profiling*
#
# Visualizing shipping mode frequencies, order regions, markets, and customer segments.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys, os
sys.path.append('..')
from src.data_loader import load_raw_data

df_raw = load_raw_data('../data/raw/Dataset_.csv')
print("Orders by Shipping Mode:")
print(df_raw['Shipping Mode'].value_counts())
# Out:
# Orders by Shipping Mode:
# Shipping Mode
# Standard Class    93210
# Second Class      31797
# First Class       24453
# Same Day           8589
# Name: count, dtype: int64
