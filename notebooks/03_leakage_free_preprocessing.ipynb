# %% [markdown]
# # 🔬 Research Notebook 03: Leakage-Free Preprocessing & Dataset Generation (Step 4)
# ### *Generating data/processed/pre_shipment_dataset.csv*
#
# Filtering target and dropping post-checkout leakage features.

# %%
import pandas as pd
import sys, os
sys.path.append('..')
from src.data_loader import load_raw_data
from src.preprocessing import create_leakage_free_dataset

df_raw = load_raw_data('../data/raw/Dataset_.csv')
df_pre = create_leakage_free_dataset(df_raw, output_path='../data/processed/pre_shipment_dataset.csv')
print(f"Pre-shipment dataset shape: {df_pre.shape}")
# Out:
#       [STEP 4] Leakage-Free Dataset Saved: ../data/processed/pre_shipment_dataset.csv (158,049 rows, 40 columns)
# Pre-shipment dataset shape: (158049, 40)
